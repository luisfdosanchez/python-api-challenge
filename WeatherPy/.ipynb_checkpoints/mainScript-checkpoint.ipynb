# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import pprint
from citipy import citipy
from api_keys import api_key
from datetime import datetime, timezone, tzinfo, timedelta

#URL and units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Output File (CSV)
outputpath=os.path.join(".","output_data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities=[]
countries=[]
lat_true=[]
lng_true=[]

# Create a set of random lat and lng combinations
#for x in range(1,19,1):
#    lowlim=float((90-((x-1)*10)))
#    highlim=float(((90-10)-((x-1)*10)))
#    lats = np.random.uniform(low=-lowlim, high=highlim, size=300)
#    lngs = np.random.uniform(low=-180.000, high=180.000, size=300)
#    lat_lngs.append([lats,lngs])

lats = np.random.uniform(low=-90.000, high=90.000, size=4000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=4000)
lat_lngs=zip(lats,lngs)
lat_lngs=pd.DataFrame(lat_lngs)


# Identify nearest city for each lat, lng combination
#for lat_lng in lat_lngs:
for index, row in lat_lngs.iterrows():
    city = citipy.nearest_city(row[0], row[1]).city_name
    country = citipy.nearest_city(row[0], row[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
print(len(cities))
cities=pd.DataFrame(zip(cities,countries))
cities=cities.rename(columns={0:'City',1:'Country'})
cities.head()
# Out:
# 1205
#                     City Country
# 0                 hobart      au
# 1         guerrero negro      mx
# 2               yarovoye      ru
# 3  los llanos de aridane      es
# 4           punta arenas      cl

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
results=[]

print(f"Beginning Data Retrieval")
print(f"---------------------------")
for index,row in cities.iterrows():
    query_url=f"{url}appid={api_key}&q={row[0]},{row[1]}&units={units}"
    response=requests.get(query_url).json()
    if response['cod']==200:
        print(f"Processing record {index} | {row[0]},{row[1]}")
        fecha=str(datetime.now(timezone(timedelta(seconds=response['timezone']))))
        results.append([
            response['name'],
            response['sys']['country'],
            fecha[0:10],
            fecha[11:16],
            response['coord']['lat'],
            response['coord']['lon'],
            response['main']['temp'],
            response['main']['temp_min'],
            response['main']['temp_max'],
            response['main']['humidity'],
            response['clouds']['all'],
            response['wind']['speed'],
        ])
    else:
        print(f"City not found. Skipping...")
        
results=pd.DataFrame(results)
results=results.rename(columns={
    0:'City',
    1:'Country',
    2:'Date',
    3:'Time',
    4:'Lat',
    5:'Lon',
    6:'Temp',
    7:'Min',
    8:'Max',
    9:'Humidity',
    10:'Cloudiness',
    11:'Wind_speed'
})
print(f"---------------------------")
print(f"Data Retrieval Complete")
print(f"---------------------------")
results.head()
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing record 0 | hobart,au
# Processing record 1 | guerrero negro,mx
# Processing record 2 | yarovoye,ru
# Processing record 3 | los llanos de aridane,es
# Processing record 4 | punta arenas,cl
# Processing record 5 | neuquen,ar
# Processing record 6 | tasiilaq,gl
# Processing record 7 | new norfolk,au
# Processing record 8 | rikitea,pf
# Processing record 9 | bandarbeyla,so
# City not found. Skipping...
# Processing record 11 | sibolga,id
# Processing record 12 | nara,ml
# Processing record 13 | tuktoyaktuk,ca
# Processing record 14 | willowmore,za
# Processing record 15 | butaritari,ki
# Processing record 16 | coquimbo,cl
# Processing record 17 | arrifes,pt
# Processing record 18 | salinopolis,br
# Processing record 19 | thompson,ca
# Processing record 20 | kualakapuas,id
# Processing record 21 | qaanaaq,gl
# Processing record 22 | vaini,to
# Processing record 23 | broken hill,au
# Processing record 24 | cape town,za
# Processing record 25 | yellowknife,ca
# Processing record 26 | ushuaia,ar
# Processing record 27 | umea,se
# Processing record 28 | hilo,us
# Processing record 29 | hithadhoo,mv
# Processing record 30 | atuona,pf
# Processing record 31 | cambridge,us
# Processing record 32 | batesville,us
# Processing record 33 | vao,nc
# City not found. Skipping...
# Processing record 35 | korla,cn
# Processing record 36 | busselton,au
# Processing record 37 | jamestown,sh
# Processing record 38 | albany,au
# Processing record 39 | carnarvon,au
# Processing record 40 | salalah,om
# Processing record 41 | chapada dos guimaraes,br
# Processing record 42 | san jeronimo,mx
# Processing record 43 | saldanha,za
# Processing record 44 | luderitz,na
# Processing record 45 | lompoc,us
# Processing record 46 | paamiut,gl
# Processing record 47 | avarua,ck
# Processing record 48 | kodiak,us
# City not found. Skipping...
# Processing record 50 | coihaique,cl
# Processing record 51 | maniitsoq,gl
# Processing record 52 | torbay,ca
# Processing record 53 | caravelas,br
# Processing record 54 | lebu,cl
# Processing record 55 | bredasdorp,za
# City not found. Skipping...
# City not found. Skipping...
# Processing record 58 | puerto ayora,ec
# Processing record 59 | granger,us
# Processing record 60 | nuevo ideal,mx
# Processing record 61 | castro,cl
# Processing record 62 | ilula,tz
# Processing record 63 | xinzhi,cn
# Processing record 64 | cookeville,us
# Processing record 65 | thabazimbi,za
# Processing record 66 | eureka,us
# Processing record 67 | ilo,pe
# Processing record 68 | itarema,br
# Processing record 69 | paita,pe
# Processing record 70 | saint george,bm
# Processing record 71 | minatitlan,mx
# Processing record 72 | mizdah,ly
# Processing record 73 | vila velha,br
# City not found. Skipping...
# Processing record 75 | dingle,ie
# Processing record 76 | muros,es
# Processing record 77 | saskylakh,ru
# Processing record 78 | kapaa,us
# Processing record 79 | hasaki,jp
# Processing record 80 | srednekolymsk,ru
# Processing record 81 | saint-augustin,ca
# Processing record 82 | hermanus,za
# City not found. Skipping...
# Processing record 84 | mar del plata,ar
# City not found. Skipping...
# Processing record 86 | banjar,id
# City not found. Skipping...
# Processing record 88 | arraial do cabo,br
# Processing record 89 | quatre cocos,mu
# City not found. Skipping...
# Processing record 91 | bonthe,sl
# Processing record 92 | saint-pierre,pm
# Processing record 93 | yertsevo,ru
# Processing record 94 | palmas bellas,pa
# Processing record 95 | sao joao da barra,br
# City not found. Skipping...
# Processing record 97 | kurilsk,ru
# Processing record 98 | nikolskoye,ru
# City not found. Skipping...
# Processing record 100 | lagoa,pt
# Processing record 101 | bluff,nz
# City not found. Skipping...
# Processing record 103 | severo-kurilsk,ru
# Processing record 104 | timbiqui,co
# Processing record 105 | ambatofinandrahana,mg
# Processing record 106 | imbituba,br
# City not found. Skipping...
# Processing record 108 | cockburn town,bs
# City not found. Skipping...
# City not found. Skipping...
# Processing record 111 | ugoofaaru,mv
# City not found. Skipping...
# Processing record 113 | nishihara,jp
# Processing record 114 | biltine,td
# Processing record 115 | biak,id
# Processing record 116 | vila franca do campo,pt
# Processing record 117 | saint-andre-avellin,ca
# Processing record 118 | aklavik,ca
# Processing record 119 | bridlington,gb
# Processing record 120 | talnakh,ru
# Processing record 121 | constitucion,mx
# City not found. Skipping...
# Processing record 123 | villa maria,ar
# Processing record 124 | provost,ca
# Processing record 125 | basco,ph
# Processing record 126 | linxia,cn
# Processing record 127 | acapulco,mx
# Processing record 128 | kavieng,pg
# Processing record 129 | san carlos de bariloche,ar
# Processing record 130 | hami,cn
# Processing record 131 | yumen,cn
# Processing record 132 | tazmalt,dz
# Processing record 133 | srandakan,id
# Processing record 134 | port alfred,za
# Processing record 135 | touros,br
# Processing record 136 | sungairaya,id
# Processing record 137 | viedma,ar
# Processing record 138 | isangel,vu
# Processing record 139 | myanaung,mm
# City not found. Skipping...
# Processing record 141 | tonantins,br
# Processing record 142 | nicolas bravo,mx
# City not found. Skipping...
# Processing record 144 | port moresby,pg
# Processing record 145 | taltal,cl
# Processing record 146 | platanos,gr
# Processing record 147 | sisimiut,gl
# Processing record 148 | mount gambier,au
# City not found. Skipping...
# Processing record 150 | nanortalik,gl
# Processing record 151 | bagdarin,ru
# Processing record 152 | saint-philippe,re
# Processing record 153 | pangody,ru
# Processing record 154 | cabo san lucas,mx
# Processing record 155 | kruisfontein,za
# City not found. Skipping...
# Processing record 157 | marawi,sd
# Processing record 158 | kijang,id
# Processing record 159 | dauriya,ru
# Processing record 160 | poddorye,ru
# City not found. Skipping...
# Processing record 162 | camacha,pt
# City not found. Skipping...
# Processing record 164 | san patricio,mx
# Processing record 165 | manokwari,id
# City not found. Skipping...
# Processing record 167 | bathsheba,bb
# Processing record 168 | omsukchan,ru
# Processing record 169 | clyde river,ca
# Processing record 170 | bodden town,ky
# City not found. Skipping...
# Processing record 172 | yerbogachen,ru
# Processing record 173 | narsaq,gl
# Processing record 174 | namibe,ao
# Processing record 175 | longyearbyen,sj
# Processing record 176 | azanka,ru
# Processing record 177 | dikson,ru
# Processing record 178 | abha,sa
# Processing record 179 | barrow,us
# Processing record 180 | verkhniy avzyan,ru
# Processing record 181 | kwinana,au
# Processing record 182 | norman wells,ca
# Processing record 183 | fortuna,us
# Processing record 184 | strezhevoy,ru
# Processing record 185 | pevek,ru
# City not found. Skipping...
# Processing record 187 | ancud,cl
# Processing record 188 | jawhar,so
# Processing record 189 | pinega,ru
# Processing record 190 | zemio,cf
# Processing record 191 | provideniya,ru
# Processing record 192 | kawalu,id
# Processing record 193 | oum hadjer,td
# City not found. Skipping...
# Processing record 195 | husavik,is
# Processing record 196 | juneau,us
# City not found. Skipping...
# Processing record 198 | oktyabrskoye,ru
# Processing record 199 | necochea,ar
# Processing record 200 | brande,dk
# Processing record 201 | bam,ir
# Processing record 202 | rodino,ru
# City not found. Skipping...
# City not found. Skipping...
# Processing record 205 | lavrentiya,ru
# Processing record 206 | jalu,ly
# Processing record 207 | solnechnyy,ru
# Processing record 208 | the hammocks,us
# Processing record 209 | ribeira grande,pt
# City not found. Skipping...
# Processing record 211 | puerto escondido,mx
# Processing record 212 | birjand,ir
# Processing record 213 | port elizabeth,za
# Processing record 214 | kloulklubed,pw
# Processing record 215 | sao raimundo das mangabeiras,br
# Processing record 216 | manzanillo,mx
# Processing record 217 | zeya,ru
# Processing record 218 | klaksvik,fo
# Processing record 219 | mahebourg,mu
# Processing record 220 | umm kaddadah,sd
# Processing record 221 | ambon,id
# Processing record 222 | zhigansk,ru
# Processing record 223 | chuy,uy
# Processing record 224 | quelimane,mz
# Processing record 225 | cajazeiras,br
# Processing record 226 | lomza,pl
# Processing record 227 | lakes entrance,au
# Processing record 228 | ayagoz,kz
# Processing record 229 | scarborough,gb
# Processing record 230 | abu zabad,sd
# City not found. Skipping...
# Processing record 232 | ust-maya,ru
# Processing record 233 | pangnirtung,ca
# Processing record 234 | ha,bt
# Processing record 235 | mykhaylivka,ua
# Processing record 236 | sur,om
# Processing record 237 | petropavlovsk-kamchatskiy,ru
# Processing record 238 | rocha,uy
# City not found. Skipping...
# Processing record 240 | ponta do sol,cv
# Processing record 241 | talaya,ru
# Processing record 242 | upernavik,gl
# Processing record 243 | sinnamary,gf
# Processing record 244 | kashan,ir
# Processing record 245 | giyani,za
# Processing record 246 | cidreira,br
# Processing record 247 | katsuura,jp
# Processing record 248 | dunmore town,bs
# Processing record 249 | lianzhou,cn
# Processing record 250 | anadyr,ru
# Processing record 251 | bethel,us
# Processing record 252 | haines junction,ca
# Processing record 253 | chokurdakh,ru
# City not found. Skipping...
# Processing record 255 | northam,au
# Processing record 256 | minab,ir
# Processing record 257 | nizhnekamsk,ru
# Processing record 258 | faanui,pf
# Processing record 259 | tarancon,es
# Processing record 260 | harwich,us
# Processing record 261 | iqaluit,ca
# Processing record 262 | kahului,us
# Processing record 263 | davila,ph
# City not found. Skipping...
# Processing record 265 | port hardy,ca
# Processing record 266 | ergani,tr
# Processing record 267 | yulara,au
# Processing record 268 | panambi,br
# City not found. Skipping...
# Processing record 270 | nantucket,us
# Processing record 271 | naifaru,mv
# Processing record 272 | sokoto,ng
# Processing record 273 | kalmar,se
# Processing record 274 | sinjar,iq
# Processing record 275 | hendrina,za
# Processing record 276 | ouadda,cf
# Processing record 277 | rio gallegos,ar
# Processing record 278 | wellington,ca
# City not found. Skipping...
# Processing record 280 | khatanga,ru
# Processing record 281 | nove mesto na morave,cz
# Processing record 282 | chirongui,yt
# Processing record 283 | oda,jp
# Processing record 284 | aviles,es
# Processing record 285 | novokayakent,ru
# Processing record 286 | tuatapere,nz
# Processing record 287 | mikkeli,fi
# Processing record 288 | huinan,cn
# Processing record 289 | ilulissat,gl
# Processing record 290 | puerto santander,co
# Processing record 291 | lazaro cardenas,mx
# Processing record 292 | grand-couronne,fr
# Processing record 293 | tripoli,gr
# Processing record 294 | kyabe,td
# Processing record 295 | galle,lk
# Processing record 296 | finschhafen,pg
# Processing record 297 | leningradskiy,ru
# Processing record 298 | yelovo,ru
# Processing record 299 | kaitangata,nz
# City not found. Skipping...
# Processing record 301 | praia da vitoria,pt
# Processing record 302 | agadir,ma
# City not found. Skipping...
# Processing record 304 | umm lajj,sa
# Processing record 305 | nuuk,gl
# Processing record 306 | dryden,ca
# City not found. Skipping...
# Processing record 308 | parkes,au
# Processing record 309 | bonavista,ca
# Processing record 310 | tholen,nl
# Processing record 311 | winslow,us
# Processing record 312 | san vicente,ph
# City not found. Skipping...
# City not found. Skipping...
# Processing record 315 | kharp,ru
# Processing record 316 | lukovetskiy,ru
# Processing record 317 | zykovo,ru
# Processing record 318 | mokhotlong,ls
# Processing record 319 | victoria,sc
# Processing record 320 | seymour,us
# Processing record 321 | kieta,pg
# Processing record 322 | ulladulla,au
# Processing record 323 | sarkand,kz
# Processing record 324 | macenta,gn
# Processing record 325 | ceres,za
# Processing record 326 | trincomalee,lk
# Processing record 327 | sao lourenco do sul,br
# Processing record 328 | mumford,gh
# Processing record 329 | ust-kuyga,ru
# Processing record 330 | dzilam gonzalez,mx
# Processing record 331 | nouakchott,mr
# Processing record 332 | dzhebariki-khaya,ru
# Processing record 333 | port macquarie,au
# Processing record 334 | luwuk,id
# Processing record 335 | chernyshevskiy,ru
# Processing record 336 | okha,ru
# Processing record 337 | flinders,au
# Processing record 338 | nouadhibou,mr
# Processing record 339 | sundsvall,se
# Processing record 340 | port hawkesbury,ca
# Processing record 341 | dangriga,bz
# Processing record 342 | karasjok,no
# Processing record 343 | jiexiu,cn
# Processing record 344 | sorland,no
# Processing record 345 | tarauaca,br
# Processing record 346 | verkhoyansk,ru
# Processing record 347 | enderby,ca
# Processing record 348 | bambous virieux,mu
# Processing record 349 | aykhal,ru
# Processing record 350 | salto del guaira,py
# Processing record 351 | buala,sb
# Processing record 352 | forestville,ca
# Processing record 353 | huarmey,pe
# Processing record 354 | esperance,au
# Processing record 355 | santiago del estero,ar
# Processing record 356 | songea,tz
# Processing record 357 | acari,pe
# Processing record 358 | alekseyevsk,ru
# Processing record 359 | gouyave,gd
# Processing record 360 | ostrovnoy,ru
# Processing record 361 | kavaratti,in
# Processing record 362 | antofagasta,cl
# Processing record 363 | guia lopes da laguna,br
# City not found. Skipping...
# Processing record 365 | te anau,nz
# Processing record 366 | sorong,id
# Processing record 367 | sabha,jo
# Processing record 368 | betamcherla,in
# Processing record 369 | hemsedal,no
# Processing record 370 | solwezi,zm
# Processing record 371 | montague,ca
# Processing record 372 | geraldton,au
# Processing record 373 | east london,za
# Processing record 374 | gambela,et
# Processing record 375 | danielskuil,za
# Processing record 376 | gwadar,pk
# Processing record 377 | luanda,ao
# Processing record 378 | veshenskaya,ru
# Processing record 379 | san cristobal,ec
# Processing record 380 | road town,vg
# Processing record 381 | ojinaga,mx
# Processing record 382 | lorengau,pg
# Processing record 383 | ossora,ru
# Processing record 384 | fairbanks,us
# Processing record 385 | sechura,pe
# Processing record 386 | tilichiki,ru
# Processing record 387 | komsomolskiy,ru
# Processing record 388 | praya,id
# Processing record 389 | nyurba,ru
# Processing record 390 | carutapera,br
# Processing record 391 | hay river,ca
# Processing record 392 | inhambane,mz
# Processing record 393 | khorixas,na
# Processing record 394 | kataysk,ru
# City not found. Skipping...
# Processing record 396 | sola,vu
# Processing record 397 | muscat,om
# Processing record 398 | hofn,is
# City not found. Skipping...
# Processing record 400 | datong,cn
# Processing record 401 | otradnoye,ru
# Processing record 402 | chicama,pe
# Processing record 403 | chumikan,ru
# Processing record 404 | alanya,tr
# Processing record 405 | trairi,br
# Processing record 406 | naze,jp
# City not found. Skipping...
# Processing record 408 | korem,et
# Processing record 409 | kennett,us
# City not found. Skipping...
# Processing record 411 | frunze,ua
# Processing record 412 | farkhor,tj
# Processing record 413 | miles city,us
# Processing record 414 | vanavara,ru
# Processing record 415 | banepa,np
# Processing record 416 | pochutla,mx
# Processing record 417 | sioux lookout,ca
# Processing record 418 | north bend,us
# Processing record 419 | campobello di mazara,it
# Processing record 420 | madang,pg
# Processing record 421 | krosno,pl
# Processing record 422 | amga,ru
# Processing record 423 | maceio,br
# Processing record 424 | mehamn,no
# Processing record 425 | lima,pe
# Processing record 426 | adrar,dz
# Processing record 427 | griffith,au
# Processing record 428 | ingham,au
# Processing record 429 | corpus christi,py
# Processing record 430 | shimoda,jp
# Processing record 431 | sitka,us
# Processing record 432 | nome,us
# Processing record 433 | chino valley,us
# Processing record 434 | karancskeszi,hu
# Processing record 435 | hambantota,lk
# Processing record 436 | kortkeros,ru
# Processing record 437 | kirakira,sb
# Processing record 438 | asyut,eg
# Processing record 439 | grand gaube,mu
# Processing record 440 | sao gabriel da cachoeira,br
# Processing record 441 | half moon bay,us
# Processing record 442 | susanville,us
# Processing record 443 | vanimo,pg
# Processing record 444 | zaraza,ve
# City not found. Skipping...
# City not found. Skipping...
# Processing record 447 | great falls,us
# Processing record 448 | rundu,na
# Processing record 449 | banda aceh,id
# Processing record 450 | torbat-e jam,ir
# Processing record 451 | manavgat,tr
# Processing record 452 | mao,td
# Processing record 453 | henties bay,na
# Processing record 454 | lethem,gy
# Processing record 455 | ryotsu,jp
# Processing record 456 | seoul,kr
# Processing record 457 | fria,gn
# Processing record 458 | ozu,jp
# Processing record 459 | agara,ge
# City not found. Skipping...
# Processing record 461 | coahuayana,mx
# Processing record 462 | moose factory,ca
# Processing record 463 | gawler,au
# Processing record 464 | lithakia,gr
# Processing record 465 | qandala,so
# Processing record 466 | manado,id
# City not found. Skipping...
# City not found. Skipping...
# Processing record 469 | derzhavinsk,kz
# Processing record 470 | ixtapa,mx
# Processing record 471 | tiksi,ru
# Processing record 472 | mundo nuevo,mx
# Processing record 473 | venado tuerto,ar
# Processing record 474 | kon tum,vn
# Processing record 475 | mukhen,ru
# Processing record 476 | deputatskiy,ru
# City not found. Skipping...
# Processing record 478 | windhoek,na
# Processing record 479 | tocopilla,cl
# Processing record 480 | vavuniya,lk
# Processing record 481 | bhera,pk
# Processing record 482 | toora-khem,ru
# Processing record 483 | tomatlan,mx
# Processing record 484 | barcelona,ph
# Processing record 485 | cairns,au
# Processing record 486 | binzhou,cn
# Processing record 487 | olga,ru
# Processing record 488 | okhotsk,ru
# Processing record 489 | praxedis guerrero,mx
# Processing record 490 | loikaw,mm
# Processing record 491 | port-gentil,ga
# Processing record 492 | cap-aux-meules,ca
# City not found. Skipping...
# Processing record 494 | madera,mx
# City not found. Skipping...
# City not found. Skipping...
# Processing record 497 | abbeville,us
# City not found. Skipping...
# Processing record 499 | manakara,mg
# Processing record 500 | erzin,ru
# City not found. Skipping...
# Processing record 502 | souillac,mu
# Processing record 503 | gamba,ga
# City not found. Skipping...
# Processing record 505 | keetmanshoop,na
# City not found. Skipping...
# City not found. Skipping...
# Processing record 508 | broome,au
# Processing record 509 | bilma,ne
# Processing record 510 | kargasok,ru
# Processing record 511 | careiro da varzea,br
# Processing record 512 | georgetown,sh
# Processing record 513 | dickinson,us
# Processing record 514 | port lincoln,au
# Processing record 515 | agucadoura,pt
# Processing record 516 | riohacha,co
# Processing record 517 | zhuzhou,cn
# Processing record 518 | capreol,ca
# Processing record 519 | chihuahua,mx
# Processing record 520 | winterberg,de
# Processing record 521 | aqtobe,kz
# Processing record 522 | samarai,pg
# City not found. Skipping...
# City not found. Skipping...
# Processing record 525 | alabaster,us
# Processing record 526 | kerema,pg
# Processing record 527 | lumeje,ao
# Processing record 528 | corrales,pe
# Processing record 529 | batemans bay,au
# Processing record 530 | uvat,ru
# Processing record 531 | rawson,ar
# Processing record 532 | tehri,in
# Processing record 533 | wuwei,cn
# Processing record 534 | dedougou,bf
# Processing record 535 | atherton,au
# Processing record 536 | cacimba de dentro,br
# City not found. Skipping...
# Processing record 538 | lucea,jm
# Processing record 539 | kudahuvadhoo,mv
# Processing record 540 | bahia honda,cu
# Processing record 541 | alofi,nu
# Processing record 542 | apatin,rs
# Processing record 543 | orlik,ru
# Processing record 544 | almaznyy,ru
# Processing record 545 | la libertad,sv
# Processing record 546 | basoko,cd
# Processing record 547 | berlevag,no
# Processing record 548 | grindavik,is
# Processing record 549 | port hedland,au
# Processing record 550 | takoradi,gh
# Processing record 551 | san jose de buan,ph
# Processing record 552 | beloha,mg
# Processing record 553 | paracatu,br
# Processing record 554 | veraval,in
# Processing record 555 | anloga,gh
# Processing record 556 | keti bandar,pk
# Processing record 557 | lichuan,cn
# Processing record 558 | freiburg,de
# Processing record 559 | liberal,us
# Processing record 560 | mecca,sa
# Processing record 561 | tevriz,ru
# Processing record 562 | east stroudsburg,us
# Processing record 563 | labuhan,id
# Processing record 564 | qidong,cn
# Processing record 565 | kaura namoda,ng
# Processing record 566 | manaus,br
# Processing record 567 | hobyo,so
# Processing record 568 | buhe,cn
# Processing record 569 | porto nacional,br
# Processing record 570 | buraydah,sa
# City not found. Skipping...
# Processing record 572 | la ronge,ca
# Processing record 573 | malacacheta,br
# City not found. Skipping...
# City not found. Skipping...
# Processing record 576 | tautira,pf
# Processing record 577 | kimbe,pg
# Processing record 578 | puerto carreno,co
# Processing record 579 | ola,ru
# Processing record 580 | mount isa,au
# Processing record 581 | keningau,my
# Processing record 582 | tefe,br
# Processing record 583 | maracacume,br
# Processing record 584 | cherskiy,ru
# Processing record 585 | ormara,pk
# Processing record 586 | kasempa,zm
# Processing record 587 | college,us
# Processing record 588 | oranjestad,aw
# Processing record 589 | auki,sb
# City not found. Skipping...
# Processing record 591 | ternate,id
# City not found. Skipping...
# Processing record 593 | cleveland,us
# Processing record 594 | abonnema,ng
# Processing record 595 | kununurra,au
# Processing record 596 | bandar-e anzali,ir
# Processing record 597 | dharur,in
# City not found. Skipping...
# Processing record 599 | mangan,in
# Processing record 600 | yichun,cn
# Processing record 601 | mega,et
# Processing record 602 | villa guerrero,mx
# Processing record 603 | yoichi,jp
# Processing record 604 | lyuban,ru
# Processing record 605 | yar-sale,ru
# Processing record 606 | kalmanka,ru
# Processing record 607 | cam ranh,vn
# Processing record 608 | sogne,no
# Processing record 609 | leshukonskoye,ru
# Processing record 610 | osmena,ph
# City not found. Skipping...
# Processing record 612 | hamilton,bm
# Processing record 613 | egvekinot,ru
# Processing record 614 | durant,us
# Processing record 615 | cutervo,pe
# Processing record 616 | port hueneme,us
# Processing record 617 | itacoatiara,br
# Processing record 618 | wanning,cn
# Processing record 619 | choma,zm
# Processing record 620 | mitsamiouli,km
# City not found. Skipping...
# Processing record 622 | moree,au
# Processing record 623 | poretskoye,ru
# Processing record 624 | seguin,us
# Processing record 625 | tabou,ci
# Processing record 626 | fort-shevchenko,kz
# City not found. Skipping...
# Processing record 628 | sao filipe,cv
# Processing record 629 | kaliganj,bd
# Processing record 630 | bismarck,us
# Processing record 631 | the valley,ai
# Processing record 632 | bela vista do paraiso,br
# Processing record 633 | dunedin,nz
# Processing record 634 | cayenne,gf
# Processing record 635 | awbari,ly
# City not found. Skipping...
# Processing record 637 | motala,se
# Processing record 638 | kennewick,us
# City not found. Skipping...
# Processing record 640 | harper,lr
# Processing record 641 | opuwo,na
# Processing record 642 | rupert,us
# Processing record 643 | haimen,cn
# Processing record 644 | kingsland,us
# Processing record 645 | kalianget,id
# Processing record 646 | boa vista,br
# Processing record 647 | pingliang,cn
# Processing record 648 | awjilah,ly
# Processing record 649 | kiama,au
# City not found. Skipping...
# Processing record 651 | prince rupert,ca
# Processing record 652 | debre tabor,et
# Processing record 653 | sulphur springs,us
# City not found. Skipping...
# Processing record 655 | daru,pg
# Processing record 656 | sahy,sk
# Processing record 657 | antalaha,mg
# Processing record 658 | morros,br
# City not found. Skipping...
# Processing record 660 | bogorodsk,ru
# Processing record 661 | itupiranga,br
# Processing record 662 | djambala,cg
# Processing record 663 | winnemucca,us
# Processing record 664 | boone,us
# Processing record 665 | atambua,id
# Processing record 666 | muli,mv
# Processing record 667 | nola,cf
# Processing record 668 | sabang,id
# Processing record 669 | halifax,ca
# City not found. Skipping...
# City not found. Skipping...
# Processing record 672 | wanlaweyn,so
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing record 676 | ziro,in
# Processing record 677 | santa marta,co
# Processing record 678 | sao jose da coroa grande,br
# Processing record 679 | manta,ec
# Processing record 680 | sarankhola,bd
# Processing record 681 | cooma,au
# Processing record 682 | kaeo,nz
# City not found. Skipping...
# Processing record 684 | sheboygan,us
# Processing record 685 | panama city,us
# Processing record 686 | astaneh-ye ashrafiyeh,ir
# Processing record 687 | udachnyy,ru
# Processing record 688 | daoukro,ci
# Processing record 689 | beira,mz
# Processing record 690 | margate,za
# Processing record 691 | linhares,br
# Processing record 692 | karatuzskoye,ru
# City not found. Skipping...
# Processing record 694 | oussouye,sn
# Processing record 695 | russell,nz
# Processing record 696 | tsiroanomandidy,mg
# Processing record 697 | den helder,nl
# Processing record 698 | kidal,ml
# Processing record 699 | aksarka,ru
# Processing record 700 | beaverton,ca
# City not found. Skipping...
# Processing record 702 | fuyu,cn
# Processing record 703 | kindu,cd
# Processing record 704 | dese,et
# Processing record 705 | aripuana,br
# Processing record 706 | bathurst,ca
# City not found. Skipping...
# Processing record 708 | helong,cn
# Processing record 709 | beringovskiy,ru
# Processing record 710 | olinda,br
# Processing record 711 | skibbereen,ie
# Processing record 712 | pringsewu,id
# Processing record 713 | dwarka,in
# Processing record 714 | zapolyarnyy,ru
# Processing record 715 | baripada,in
# Processing record 716 | denpasar,id
# Processing record 717 | kostomuksha,ru
# Processing record 718 | ornskoldsvik,se
# Processing record 719 | cagliari,it
# Processing record 720 | atar,mr
# City not found. Skipping...
# City not found. Skipping...
# Processing record 723 | gewane,et
# City not found. Skipping...
# Processing record 725 | athens,us
# Processing record 726 | townsville,au
# Processing record 727 | comodoro rivadavia,ar
# Processing record 728 | hirara,jp
# Processing record 729 | conde,br
# Processing record 730 | dudinka,ru
# Processing record 731 | pasighat,in
# City not found. Skipping...
# Processing record 733 | guangyuan,cn
# Processing record 734 | tuy hoa,vn
# Processing record 735 | boghesti,ro
# Processing record 736 | hervey bay,au
# Processing record 737 | loa janan,id
# Processing record 738 | havoysund,no
# Processing record 739 | koungou,yt
# City not found. Skipping...
# Processing record 741 | ostersund,se
# Processing record 742 | besancon,fr
# Processing record 743 | carbonia,it
# Processing record 744 | amos,ca
# Processing record 745 | copiapo,cl
# Processing record 746 | tazovskiy,ru
# Processing record 747 | roma,au
# Processing record 748 | diffa,ne
# Processing record 749 | guarapari,br
# Processing record 750 | cardenas,mx
# Processing record 751 | hajduboszormeny,hu
# Processing record 752 | matara,lk
# Processing record 753 | batagay,ru
# City not found. Skipping...
# City not found. Skipping...
# Processing record 756 | saint-ambroise,ca
# Processing record 757 | yeniseysk,ru
# Processing record 758 | mina,mx
# Processing record 759 | ust-kalmanka,ru
# Processing record 760 | reconquista,ar
# Processing record 761 | urucara,br
# Processing record 762 | cortez,us
# Processing record 763 | cascais,pt
# Processing record 764 | medak,in
# Processing record 765 | anchorage,us
# Processing record 766 | soyo,ao
# Processing record 767 | charleston,us
# Processing record 768 | thinadhoo,mv
# Processing record 769 | inuvik,ca
# Processing record 770 | angoram,pg
# Processing record 771 | taoudenni,ml
# Processing record 772 | tulum,mx
# Processing record 773 | federal way,us
# City not found. Skipping...
# Processing record 775 | axim,gh
# Processing record 776 | krasnooktyabrskiy,ru
# Processing record 777 | ashland,us
# Processing record 778 | north branch,us
# Processing record 779 | pervomayskiy,ru
# Processing record 780 | boromo,bf
# Processing record 781 | ilhabela,br
# Processing record 782 | nemuro,jp
# Processing record 783 | belyy yar,ru
# Processing record 784 | khuzdar,pk
# Processing record 785 | tula,mx
# City not found. Skipping...
# Processing record 787 | san jose,gt
# Processing record 788 | dalby,au
# Processing record 789 | nogliki,ru
# Processing record 790 | alta floresta,br
# Processing record 791 | mastic beach,us
# Processing record 792 | magelang,id
# City not found. Skipping...
# Processing record 794 | maues,br
# Processing record 795 | tevaitoa,pf
# Processing record 796 | westport,ie
# Processing record 797 | merauke,id
# Processing record 798 | lisakovsk,kz
# City not found. Skipping...
# Processing record 800 | bandipur,in
# City not found. Skipping...
# City not found. Skipping...
# Processing record 803 | werkendam,nl
# Processing record 804 | marihatag,ph
# Processing record 805 | lashio,mm
# Processing record 806 | araouane,ml
# City not found. Skipping...
# City not found. Skipping...
# Processing record 809 | ramsar,ir
# Processing record 810 | nisko,pl
# Processing record 811 | yugorsk,ru
# Processing record 812 | san-pedro,ci
# Processing record 813 | os,no
# Processing record 814 | domoni,km
# Processing record 815 | male,mv
# Processing record 816 | boden,se
# Processing record 817 | yarkovo,ru
# Processing record 818 | meadow lake,ca
# Processing record 819 | brokopondo,sr
# Processing record 820 | serebryansk,kz
# Processing record 821 | mana,gf
# Processing record 822 | yenagoa,ng
# Processing record 823 | katherine,au
# Processing record 824 | damara,cf
# Processing record 825 | santa fe,cu
# Processing record 826 | jieshi,cn
# Processing record 827 | dhidhdhoo,mv
# Processing record 828 | ibra,om
# Processing record 829 | morondava,mg
# Processing record 830 | la macarena,co
# Processing record 831 | windsor,ca
# City not found. Skipping...
# City not found. Skipping...
# Processing record 834 | costinesti,ro
# Processing record 835 | zhezkazgan,kz
# Processing record 836 | domodossola,it
# Processing record 837 | morehead,pg
# Processing record 838 | havre-saint-pierre,ca
# Processing record 839 | salta,ar
# City not found. Skipping...
# Processing record 841 | kostek,ru
# Processing record 842 | killybegs,ie
# Processing record 843 | nelson bay,au
# Processing record 844 | opotiki,nz
# Processing record 845 | neiafu,to
# Processing record 846 | sangar,ru
# Processing record 847 | doka,sd
# Processing record 848 | lannion,fr
# City not found. Skipping...
# Processing record 850 | bangkalan,id
# Processing record 851 | mirabad,af
# Processing record 852 | capalnita,ro
# Processing record 853 | karratha,au
# Processing record 854 | jiujiang,cn
# Processing record 855 | upata,ve
# Processing record 856 | glenwood springs,us
# Processing record 857 | gloversville,us
# Processing record 858 | teknaf,bd
# Processing record 859 | orel-izumrud,ru
# City not found. Skipping...
# City not found. Skipping...
# Processing record 862 | ulaanbaatar,mn
# Processing record 863 | san nicolas,ph
# Processing record 864 | bambanglipuro,id
# Processing record 865 | pirenopolis,br
# Processing record 866 | kysyl-syr,ru
# Processing record 867 | ballinasloe,ie
# Processing record 868 | rock springs,us
# Processing record 869 | sept-iles,ca
# Processing record 870 | cabildo,cl
# Processing record 871 | palmer,us
# Processing record 872 | iquitos,pe
# Processing record 873 | aksu,cn
# Processing record 874 | meulaboh,id
# Processing record 875 | yuancheng,cn
# Processing record 876 | ulaangom,mn
# Processing record 877 | wadowice,pl
# Processing record 878 | joao camara,br
# Processing record 879 | abu kamal,sy
# Processing record 880 | san bernardino,py
# City not found. Skipping...
# Processing record 882 | simao,cn
# City not found. Skipping...
# Processing record 884 | salym,ru
# Processing record 885 | san policarpo,ph
# Processing record 886 | usinsk,ru
# Processing record 887 | santona,es
# Processing record 888 | navirai,br
# Processing record 889 | maldonado,uy
# Processing record 890 | nagato,jp
# Processing record 891 | montepuez,mz
# Processing record 892 | cartagena,co
# City not found. Skipping...
# Processing record 894 | najran,sa
# Processing record 895 | bubaque,gw
# Processing record 896 | vestmannaeyjar,is
# Processing record 897 | chipiona,es
# Processing record 898 | burnie,au
# Processing record 899 | jacareacanga,br
# Processing record 900 | andenes,no
# Processing record 901 | viesca,mx
# Processing record 902 | mocuba,mz
# Processing record 903 | richards bay,za
# City not found. Skipping...
# Processing record 905 | bowen,au
# Processing record 906 | kayerkan,ru
# Processing record 907 | yabassi,cm
# Processing record 908 | san benito,ph
# City not found. Skipping...
# Processing record 910 | liverpool,ca
# Processing record 911 | tessalit,ml
# Processing record 912 | qingdao,cn
# Processing record 913 | shingu,jp
# Processing record 914 | tahoua,ne
# Processing record 915 | arlit,ne
# Processing record 916 | quibor,ve
# Processing record 917 | pimentel,pe
# City not found. Skipping...
# City not found. Skipping...
# Processing record 920 | asosa,et
# Processing record 921 | mzimba,mw
# Processing record 922 | ngemplak,id
# Processing record 923 | susehri,tr
# Processing record 924 | malpura,in
# Processing record 925 | ketchikan,us
# Processing record 926 | green river,us
# Processing record 927 | vaitape,pf
# Processing record 928 | lat yao,th
# Processing record 929 | texarkana,us
# Processing record 930 | kanigiri,in
# Processing record 931 | poum,nc
# Processing record 932 | massaguet,td
# Processing record 933 | smirnykh,ru
# Processing record 934 | chapais,ca
# Processing record 935 | chapleau,ca
# Processing record 936 | felipe carrillo puerto,mx
# Processing record 937 | monte carmelo,br
# Processing record 938 | flin flon,ca
# Processing record 939 | padang,id
# Processing record 940 | duluth,us
# Processing record 941 | agdas,az
# Processing record 942 | brigantine,us
# Processing record 943 | gazanjyk,tm
# Processing record 944 | humberto de campos,br
# Processing record 945 | sahuaripa,mx
# Processing record 946 | vasudevanallur,in
# Processing record 947 | urmary,ru
# Processing record 948 | boca do acre,br
# Processing record 949 | braniewo,pl
# Processing record 950 | leh,in
# Processing record 951 | kattivakkam,in
# Processing record 952 | cruz alta,br
# Processing record 953 | strathroy,ca
# City not found. Skipping...
# Processing record 955 | banki,in
# Processing record 956 | werda,bw
# Processing record 957 | alto longa,br
# Processing record 958 | iralaya,hn
# Processing record 959 | nueva guinea,ni
# City not found. Skipping...
# Processing record 961 | de aar,za
# City not found. Skipping...
# Processing record 963 | hadano,jp
# Processing record 964 | tecoanapa,mx
# Processing record 965 | chalus,ir
# Processing record 966 | ngerengere,tz
# City not found. Skipping...
# Processing record 968 | wasilla,us
# City not found. Skipping...
# Processing record 970 | gojra,pk
# Processing record 971 | pemba,mz
# Processing record 972 | muroto,jp
# Processing record 973 | roebourne,au
# Processing record 974 | peace river,ca
# Processing record 975 | viransehir,tr
# Processing record 976 | baykit,ru
# Processing record 977 | manggar,id
# Processing record 978 | nha trang,vn
# Processing record 979 | ambilobe,mg
# Processing record 980 | santa isabel do rio negro,br
# Processing record 981 | yangambi,cd
# Processing record 982 | santa luzia,br
# Processing record 983 | slave lake,ca
# Processing record 984 | lithgow,au
# Processing record 985 | nueva imperial,cl
# Processing record 986 | bousse,bf
# Processing record 987 | bago,mm
# Processing record 988 | baixa grande,br
# City not found. Skipping...
# City not found. Skipping...
# Processing record 991 | sabaudia,it
# City not found. Skipping...
# Processing record 993 | zhovkva,ua
# Processing record 994 | talcahuano,cl
# Processing record 995 | gigmoto,ph
# Processing record 996 | pisco,pe
# Processing record 997 | pokrovsk,ru
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1000 | ochakiv,ua
# Processing record 1001 | coruripe,br
# Processing record 1002 | sosnogorsk,ru
# Processing record 1003 | calderitas,mx
# Processing record 1004 | baglung,np
# Processing record 1005 | siniscola,it
# Processing record 1006 | liepaja,lv
# Processing record 1007 | kokopo,pg
# City not found. Skipping...
# Processing record 1009 | namwala,zm
# Processing record 1010 | puri,in
# Processing record 1011 | shestakovo,ru
# Processing record 1012 | ranong,th
# Processing record 1013 | fayaoue,nc
# Processing record 1014 | pedernales,do
# Processing record 1015 | channel-port aux basques,ca
# Processing record 1016 | yining,cn
# Processing record 1017 | finnsnes,no
# Processing record 1018 | vardo,no
# Processing record 1019 | evensk,ru
# City not found. Skipping...
# Processing record 1021 | puerto suarez,bo
# Processing record 1022 | petatlan,mx
# Processing record 1023 | hun,ly
# Processing record 1024 | tongchuan,cn
# Processing record 1025 | melo,uy
# Processing record 1026 | poronaysk,ru
# City not found. Skipping...
# Processing record 1028 | nadym,ru
# City not found. Skipping...
# Processing record 1030 | parrita,cr
# Processing record 1031 | barreirinhas,br
# Processing record 1032 | kaka,tm
# Processing record 1033 | khonsa,in
# Processing record 1034 | kiunga,pg
# Processing record 1035 | uppsala,se
# Processing record 1036 | mareeba,au
# Processing record 1037 | am timan,td
# Processing record 1038 | mattawa,ca
# Processing record 1039 | vadso,no
# Processing record 1040 | paramonga,pe
# Processing record 1041 | natchitoches,us
# Processing record 1042 | byron bay,au
# Processing record 1043 | grimshaw,ca
# Processing record 1044 | mwingi,ke
# Processing record 1045 | nahan,in
# Processing record 1046 | peleduy,ru
# Processing record 1047 | mahbubabad,in
# Processing record 1048 | puerto parra,co
# Processing record 1049 | anori,br
# Processing record 1050 | nabire,id
# Processing record 1051 | angol,cl
# Processing record 1052 | iskateley,ru
# Processing record 1053 | sampit,id
# Processing record 1054 | sao felix do xingu,br
# Processing record 1055 | valparaiso,mx
# Processing record 1056 | san borja,bo
# Processing record 1057 | luorong,cn
# Processing record 1058 | chiniot,pk
# City not found. Skipping...
# Processing record 1060 | kartaly,ru
# Processing record 1061 | haverhill,us
# Processing record 1062 | odienne,ci
# Processing record 1063 | rio grande,br
# Processing record 1064 | lujan,ar
# Processing record 1065 | kamennogorsk,ru
# Processing record 1066 | tura,ru
# City not found. Skipping...
# Processing record 1068 | george town,ky
# Processing record 1069 | catio,gw
# Processing record 1070 | petrolina,br
# Processing record 1071 | constantine,dz
# City not found. Skipping...
# Processing record 1073 | behbahan,ir
# Processing record 1074 | vestmanna,fo
# Processing record 1075 | marsabit,ke
# Processing record 1076 | susangerd,ir
# Processing record 1077 | kasongo-lunda,cd
# Processing record 1078 | santa ana,gt
# Processing record 1079 | pizarro,co
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1082 | muisne,ec
# City not found. Skipping...
# Processing record 1084 | malpe,in
# City not found. Skipping...
# Processing record 1086 | tosya,tr
# Processing record 1087 | fontem,cm
# Processing record 1088 | bogandinskiy,ru
# Processing record 1089 | funtua,ng
# Processing record 1090 | gombe,ng
# Processing record 1091 | bulaevo,kz
# City not found. Skipping...
# Processing record 1093 | cobija,bo
# Processing record 1094 | brae,gb
# Processing record 1095 | mabai,cn
# Processing record 1096 | mongo,td
# City not found. Skipping...
# Processing record 1098 | barkhan,pk
# Processing record 1099 | svetlopolyansk,ru
# Processing record 1100 | imeni poliny osipenko,ru
# Processing record 1101 | cururupu,br
# Processing record 1102 | malanje,ao
# Processing record 1103 | yima,cn
# Processing record 1104 | zhangye,cn
# Processing record 1105 | barra do garcas,br
# City not found. Skipping...
# City not found. Skipping...
# Processing record 1108 | neustadt,de
# Processing record 1109 | agirish,ru
# Processing record 1110 | dauphin,ca
# Processing record 1111 | khandyga,ru
# Processing record 1112 | celestun,mx
# Processing record 1113 | sassandra,ci
# Processing record 1114 | nioaque,br
# Processing record 1115 | poso,id
# Processing record 1116 | wuda,cn
# Processing record 1117 | twin falls,us
# City not found. Skipping...
# Processing record 1119 | adwa,et
# Processing record 1120 | paraiso,mx
# Processing record 1121 | amet,in
# Processing record 1122 | yurginskoye,ru
# Processing record 1123 | polis,cy
# Processing record 1124 | krasnoufimsk,ru
# Processing record 1125 | fort morgan,us
# Processing record 1126 | iracoubo,gf
# Processing record 1127 | cherdakly,ru
# Processing record 1128 | utrera,es
# Processing record 1129 | aliwal north,za
# Processing record 1130 | lae,pg
# Processing record 1131 | alice town,bs
# Processing record 1132 | calama,cl
# Processing record 1133 | cumpas,mx
# Processing record 1134 | saint-francois,gp
# City not found. Skipping...
# Processing record 1136 | seydi,tm
# Processing record 1137 | kamenka,ru
# Processing record 1138 | mayo,ca
# Processing record 1139 | boysun,uz
# Processing record 1140 | bjornevatn,no
# Processing record 1141 | morant bay,jm
# Processing record 1142 | oleksandrivka,ua
# Processing record 1143 | santa maria,cv
# Processing record 1144 | turukhansk,ru
# City not found. Skipping...
# Processing record 1146 | afsin,tr
# Processing record 1147 | high rock,bs
# City not found. Skipping...
# Processing record 1149 | tarrafal,cv
# Processing record 1150 | plettenberg bay,za
# Processing record 1151 | mogadishu,so
# Processing record 1152 | aasiaat,gl
# Processing record 1153 | lincoln,ar
# Processing record 1154 | martapura,id
# Processing record 1155 | kungurtug,ru
# Processing record 1156 | amapa,br
# City not found. Skipping...
# Processing record 1158 | karwar,in
# Processing record 1159 | zhengjiatun,cn
# City not found. Skipping...
# Processing record 1161 | bulungu,cd
# Processing record 1162 | ippy,cf
# Processing record 1163 | chanika,tz
# Processing record 1164 | kidero,ru
# Processing record 1165 | horta,pt
# Processing record 1166 | rio tercero,ar
# Processing record 1167 | kjollefjord,no
# City not found. Skipping...
# Processing record 1169 | port blair,in
# Processing record 1170 | biskamzha,ru
# City not found. Skipping...
# Processing record 1172 | san andres,co
# Processing record 1173 | riberalta,bo
# Processing record 1174 | lamu,ke
# Processing record 1175 | pudozh,ru
# City not found. Skipping...
# Processing record 1177 | portland,au
# Processing record 1178 | shebalino,ru
# Processing record 1179 | calvinia,za
# Processing record 1180 | sarakhs,ir
# Processing record 1181 | kuopio,fi
# Processing record 1182 | mayumba,ga
# Processing record 1183 | marsh harbour,bs
# City not found. Skipping...
# Processing record 1185 | petrovskoye,ru
# Processing record 1186 | mersin,tr
# Processing record 1187 | nizhniy kuranakh,ru
# Processing record 1188 | whitehorse,ca
# City not found. Skipping...
# Processing record 1190 | bage,br
# City not found. Skipping...
# Processing record 1192 | innisfail,au
# Processing record 1193 | batangafo,cf
# Processing record 1194 | micheweni,tz
# Processing record 1195 | robertsport,lr
# Processing record 1196 | mitu,co
# Processing record 1197 | stornoway,gb
# Processing record 1198 | redmond,us
# Processing record 1199 | homa bay,ke
# Processing record 1200 | dhaka,bd
# Processing record 1201 | san juan,ar
# Processing record 1202 | baturaja,id
# Processing record 1203 | champerico,gt
# Processing record 1204 | lasem,id
# ---------------------------
# Data Retrieval Complete
# ---------------------------
#                     City Country        Date   Time    Lat     Lon   Temp  \
# 0                 Hobart      AU  2019-10-10  04:48 -42.88  147.33  46.04
# 1         Guerrero Negro      MX  2019-10-09  11:48  27.97 -114.04  75.83
# 2               Yarovoye      RU  2019-10-10  00:48  52.92   78.56  51.53
# 3  Los Llanos de Aridane      ES  2019-10-09  18:48  28.66  -17.92  72.59
# 4           Punta Arenas      CL  2019-10-09  14:48 -53.16  -70.91  48.76
#
#      Min    Max  Humidity  Cloudiness  Wind_speed
# 0  45.00  48.20        87          90        4.70
# 1  75.83  75.83        47           0       11.70
# 2  51.53  51.53        68           0        8.40
# 3  68.00  77.00        65          75       11.41
# 4  46.40  50.00        53          75       41.38

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
results.to_csv(outputpath,index=False)
results.head()
# Out:
#                     City Country        Date   Time    Lat     Lon   Temp  \
# 0                 Hobart      AU  2019-10-10  04:48 -42.88  147.33  46.04
# 1         Guerrero Negro      MX  2019-10-09  11:48  27.97 -114.04  75.83
# 2               Yarovoye      RU  2019-10-10  00:48  52.92   78.56  51.53
# 3  Los Llanos de Aridane      ES  2019-10-09  18:48  28.66  -17.92  72.59
# 4           Punta Arenas      CL  2019-10-09  14:48 -53.16  -70.91  48.76
#
#      Min    Max  Humidity  Cloudiness  Wind_speed
# 0  45.00  48.20        87          90        4.70
# 1  75.83  75.83        47           0       11.70
# 2  51.53  51.53        68           0        8.40
# 3  68.00  77.00        65          75       11.41
# 4  46.40  50.00        53          75       41.38

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
title=f'City Latitude v. Max Temperature ({time.localtime().tm_mday}/{time.localtime().tm_mon}/{time.localtime().tm_year})'
plt.title(title)
plt.ylabel('Max temperature (F)')
plt.xlabel('Latitude')
plt.grid()
plt.scatter(results['Lat'],results['Max'],edgecolors='k', s=20, linewidths=0.35)
plt.savefig("./output_data/Max_Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
title=f'City Latitude v. Humidity ({time.localtime().tm_mday}/{time.localtime().tm_mon}/{time.localtime().tm_year})'
plt.title(title)
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()
plt.ylim(0,110)
plt.scatter(results['Lat'],results['Humidity'],edgecolors='k', s=20, linewidths=0.35)
plt.savefig("./output_data/Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
title=f'City Latitude v. Cloudiness ({time.localtime().tm_mday}/{time.localtime().tm_mon}/{time.localtime().tm_year})'
plt.title(title)
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()
plt.scatter(results['Lat'],results['Cloudiness'],edgecolors='k', s=20, linewidths=0.35)
plt.savefig("./output_data/Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
title=f'City Latitude v. Wind Speed ({time.localtime().tm_mday}/{time.localtime().tm_mon}/{time.localtime().tm_year})'
plt.title(title)
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()
plt.scatter(results['Lat'],results['Wind_speed'],edgecolors='k', s=20, linewidths=0.35)
plt.savefig("./output_data/Wind_Speed.png")

# %% [markdown]
# #### Latitude vs. Temperature Range Plot

# %%
title=f'City Latitude v. Temperature Range ({time.localtime().tm_mday}/{time.localtime().tm_mon}/{time.localtime().tm_year})'
plt.title(title)
plt.ylabel('Range=Max-Min (F)')
plt.xlabel('Latitude')
plt.grid()
plt.scatter(results['Lat'],results['Max']-results['Min'],edgecolors='k', s=20, linewidths=0.35)
plt.savefig("./output_data/Range_Temperature.png")

# %% [markdown]
# ## Main findings of Weather Behaviour
#
# #### The results shown here come from a random sample of cities.
#
#
# * 1. It appears to be a relation between latitude and temperatures (we use max temperatures to have uniform temperature data). In sum, the further from the equator (latutide=0) the colder the temperature tends to be.
#
#     ![Max Temperature.png](output_data/Max_Temperature.png)
#
# * 2. Also, temperatures appear to be more extreme in latitudes further from the equator. The range (i.e. the difference between max and min temperatures during the day) tends to increase the more north or south cities are. It should be mentioned though that many cities in all latitudes show a range equal to zero.
#
#     ![Range Temperature.png](output_data/Range_Temperature.png)
#
# * 3. Humidity tends to be closer to 100% in cities located near the equator. In general, as cities are located further from the equator, the humidity variance tends to increase. That is, in these latitudes there are cities with high levels of humidity and also cities with low levels of humidity.
#
#     ![Humidity.png](output_data/Humidity.png)
#
# * 4. Wind speed and Cloudiness do not appear to have a strong connection with latitudes. There appears to be a slight increase in wind speed in extreme latitudes though.
#
#     ![Wind Speed.png](output_data/Wind_Speed.png) ![Cloudiness.png](output_data/Cloudiness.png)
